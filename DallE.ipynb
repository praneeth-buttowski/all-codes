# %%
import requests
import openai
import tkinter as tk
from PIL import Image, ImageDraw, ImageFont, ImageTk
import requests
from io import BytesIO


api_key = "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"
openai.api_key = api_key


def generate_project_summary():
    project_title = entry.get()
    
    response1 = openai.Completion.create(
        engine="text-davinci-002",
        prompt=project_title,
        max_tokens=200
    )
    generated_text = response1.choices[0].text

    response2 = openai.Image.create(
        model="image-alpha-001",
        prompt=project_title
    )
    image_url = response2['data'][0]['url']
    image_data = requests.get(image_url).content
    img = Image.open(BytesIO(image_data))
    
    # Create a new window
    result_window = tk.Toplevel()
    result_window.title(project_title)
    result_window.geometry("800x500") 

 
    text_display = tk.Label(result_window, text=generated_text, wraplength=400)
    text_display.pack()

    img = Image.open(BytesIO(image_data))
    img = img.resize((500, 500))
    img = ImageTk.PhotoImage(img)
    img_display = tk.Label(result_window, image=img)
    img_display.img = img
    img_display.pack()


# Create the main application window
app = tk.Tk()
app.title("Project Generator")

# Create an input field and a button
entry_label = tk.Label(app, text="Title:")
entry_label.pack()
entry = tk.Entry(app)
entry.pack()
generate_button = tk.Button(app, text="Go", command=generate_project_summary)
generate_button.pack()

app.mainloop()
